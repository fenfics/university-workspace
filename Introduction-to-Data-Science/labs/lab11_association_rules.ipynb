# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mlxtend.frequent_patterns import apriori, association_rules

# %%
df = pd.read_csv('./data/goodreads_data_science_books.csv')

# %%
df.head(5)
# Out:
#          authorName      bookFormat    bookId  \
# 0     Roger D. Peng           ebook  26299386
# 1   Lillian Pierson       Paperback  56751800
# 2  John D. Kelleher       Paperback  36722689
# 3   Jake Vanderplas       Paperback  26457146
# 4   Oliver Theobald  Kindle Edition  35518108
#
#                                          description  numberOfPages  \
# 0  This book describes, simply and in general ter...          154.0
# 1  Monetize your company’s data and data science ...          432.0
# 2  <b>A concise introduction to the emerging fiel...          280.0
# 3  For many researchers, Python is a first-class ...          546.0
# 4  <b> To buy the newest edition of this book (20...          168.0
#
#    numberOfRatings  numberOfReviews        publishedBy       publishedDate  \
# 0              274               39            Leanpub   September 5, 2015
# 1              231               25        For Dummies  September 15, 2021
# 2              752               89      The MIT Press      April 13, 2018
# 3              593               56     O'Reilly Media     January 3, 2017
# 4              394               18  Scatterplot Press       June 21, 2017
#
#    rating                                              title
# 0    3.74  The Art of Data Science: A Guide for Anyone Wh...
# 1    3.45              Data Science For Dummies (For Dummies
# 2    3.91                                       Data Science
# 3    4.31  Python Data Science Handbook: Essential Tools ...
# 4    4.13  Machine Learning For Absolute Beginners: A Pla...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   authorName       392 non-null    object
#  1   bookFormat       386 non-null    object
#  2   bookId           392 non-null    int64
#  3   description      379 non-null    object
#  4   numberOfPages    371 non-null    float64
#  5   numberOfRatings  392 non-null    int64
#  6   numberOfReviews  392 non-null    int64
#  7   publishedBy      271 non-null    object
#  8   publishedDate    392 non-null    object
#  9   rating           390 non-null    float64
#  10  title            392 non-null    object
# dtypes: float64(2), int64(3), object(6)
# memory usage: 33.8+ KB

# %%
# LINEAR REGRESSION

# %%
x = df[['numberOfPages', 'numberOfRatings', 'numberOfReviews']].fillna(0)
y = df['rating'].fillna(df['rating'].mean())

from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(x, y)

from sklearn.metrics import mean_absolute_error
y_predict = model.predict(x)
score = mean_absolute_error(y, y_predict)
print(score)
# Out:
# 0.366869467936553
