# %%
import pandas as pd

# %%
s1 = pd.Series([5,20,30,35,60],index=['a','b','c','d','e']);

# %%
s1
# Out:
# a     5
# b    20
# c    30
# d    35
# e    60
# dtype: int64

# %%
s1[1:3]
# Out:
# b    20
# c    30
# dtype: int64

# %%
s1[:'c']
# Out:
# a     5
# b    20
# c    30
# dtype: int64

# %%
import numpy as np

# %%
np.random.seed(1)
df1= pd.DataFrame(np.random.randint(10,50,[5,4]))
df1
# Out:
#     0   1   2   3
# 0  47  22  18  19
# 1  21  15  25  10
# 2  26  11  22  17
# 3  16  35  30  47
# 4  28  30  21  38

# %%
for index,value in df1['X'].item():
    print(f"{index} = {value}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 for index,value in df1['X'].item():
#       2     print(f"{index} = {value}")
#
# NameError: name 'df1' is not defined

# %%
np.random.seed(1)
df2= pd.DataFrame(np.random.randint(10,50,[5,4]),index = 'a b c d e'.split(),columns=list('WXYZ'))
df2
# Out:
#     W   X   Y   Z
# a  47  22  18  19
# b  21  15  25  10
# c  26  11  22  17
# d  16  35  30  47
# e  28  30  21  38

# %%
df2.loc['b']
# Out:
# W    21
# X    15
# Y    25
# Z    10
# Name: b, dtype: int32

# %%
df2.iloc[1]
# Out:
# W    21
# X    15
# Y    25
# Z    10
# Name: b, dtype: int32

# %%
df2[['W','Z']]
# Out:
#     W   Z
# a  47  19
# b  21  10
# c  26  17
# d  16  47
# e  28  38

# %%
df2.loc[['a','c'],['X','Y','Z']]
# Out:
#     X   Y   Z
# a  22  18  19
# c  11  22  17

# %%
df2.loc[['a','b']]
# Out:
#     W   X   Y   Z
# a  47  22  18  19
# b  21  15  25  10

# %%
for index, row in df2.iterrows():
    print(f"{index}: X = {row['X']}")
# Out:
# a: X = 22
# b: X = 15
# c: X = 11
# d: X = 35
# e: X = 30

# %%
for index, row in df2.iterrows():
    for col in df2.columns:
        print(row[col])
# Out:
# 47
# 22
# 18
# 19
# 21
# 15
# 25
# 10
# 26
# 11
# 22
# 17
# 16
# 35
# 30
# 47
# 28
# 30
# 21
# 38

# %%
df2>20
# Out:
#        W      X      Y      Z
# a   True   True  False  False
# b   True  False   True  False
# c   True  False   True  False
# d  False   True   True   True
# e   True   True   True   True

# %%
df2[df2>20]
# Out:
#       W     X     Y     Z
# a  47.0  22.0   NaN   NaN
# b  21.0   NaN  25.0   NaN
# c  26.0   NaN  22.0   NaN
# d   NaN  35.0  30.0  47.0
# e  28.0  30.0  21.0  38.0

# %%
df2[df2.X>20]
# Out:
#     W   X   Y   Z
# a  47  22  18  19
# d  16  35  30  47
# e  28  30  21  38

# %%
df = pd.read_csv('Sample - Superstore.csv',encoding = 'ISO-8859-1')
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 2          3  CA-2016-138688   6/12/2016   6/16/2016    Second Class
# 3          4  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# 4          5  US-2015-108966  10/11/2015  10/18/2015  Standard Class
# ...      ...             ...         ...         ...             ...
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.columns
# Out:
# Index(['Row ID', 'Order ID', 'Order Date', 'Ship Date', 'Ship Mode',
#        'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State',
#        'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category',
#        'Product Name', 'Sales', 'Quantity', 'Discount', 'Profit'],
#       dtype='object')

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df[df['Ship Mode'] == 'First Class'].groupby('Region').sum()
# Out:
#           Row ID                                           Order ID  \
# Region
# Central  1522232  CA-2016-117590CA-2016-117590CA-2016-118255CA-2...
# East     2380262  CA-2016-111682CA-2016-111682CA-2016-111682CA-2...
# South    1178876  CA-2016-119823CA-2016-127208CA-2016-127208CA-2...
# West     2417165  CA-2017-157833CA-2016-158834CA-2016-158834CA-2...
#
#                                                 Order Date  \
# Region
# Central  12/8/201612/8/20163/11/20163/11/201612/9/20171...
# East     6/17/20166/17/20166/17/20166/17/20166/17/20166...
# South    6/4/20166/12/20166/12/20164/15/20173/8/20173/8...
# West     6/17/20173/13/20163/13/20165/31/20155/31/20155...
#
#                                                  Ship Date  \
# Region
# Central  12/10/201612/10/20163/13/20163/13/201612/11/20...
# East     6/18/20166/18/20166/18/20166/18/20166/18/20166...
# South    6/6/20166/15/20166/15/20164/17/20173/11/20173/...
# West     6/20/20173/16/20163/16/20166/2/20156/2/20156/2...
# ...

# %%
df['Ship Mode'].nunique()
# Out:
# 4

# %%
df['Ship Mode'].value_counts()
# Out:
# Ship Mode
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: count, dtype: int64

# %%
s1
# Out:
# a     5
# b    20
# c    30
# d    35
# e    60
# dtype: int64

# %%
def fn(x):
    return x**2

# %%
s1.apply(fn)
# Out:
# a      25
# b     400
# c     900
# d    1225
# e    3600
# dtype: int64

# %%
s1.apply(lambda x : x**2)
# Out:
# a      25
# b     400
# c     900
# d    1225
# e    3600
# dtype: int64

# %%
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df[df['Product Name'].apply(lambda x : 'deluxe' in x.lower())]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 1          2  CA-2016-152156   11/8/2016  11/11/2016    Second Class
# 23        24  US-2017-156909   7/16/2017   7/18/2017    Second Class
# 124      125  US-2014-152030  12/26/2014  12/28/2014    Second Class
# 149      150  CA-2016-114489   12/5/2016   12/9/2016  Standard Class
# 157      158  CA-2014-104269    3/1/2014    3/6/2014    Second Class
# ...      ...             ...         ...         ...             ...
# 9310    9311  US-2016-102141   8/26/2016   8/31/2016  Standard Class
# 9351    9352  CA-2016-159009   9/23/2016   9/27/2016  Standard Class
# 9645    9646  US-2017-107979    6/8/2017   6/13/2017  Standard Class
# 9788    9789  CA-2017-144491   3/27/2017    4/1/2017  Standard Class
# 9792    9793  CA-2014-127166   5/21/2014   5/23/2014    Second Class
#
#      Customer ID     Customer Name      Segment        Country           City  \
# ...

# %%
df[df['Product Name'].apply(lambda x : 'deluxe' in x.lower())] ['Product Name'].unique()
# Out:
# array(['Hon Deluxe Fabric Upholstered Stacking Chairs, Rounded Back',
#        'Global Deluxe Stacking Chair, Gray',
#        "Global Deluxe High-Back Manager's Chair",
#        'Rogers Deluxe File Chest', 'Global Deluxe Office Fabric Chairs',
#        'Global Deluxe Steno Chair',
#        'Boston 1645 Deluxe Heavier-Duty Electric Pencil Sharpener',
#        'Deluxe Rollaway Locking File with Drawer',
#        'Deluxe Chalkboard Eraser Cleaner',
#        'Deluxe Heavy-Duty Vinyl Round Ring Binder',
#        'Hon Deluxe Fabric Upholstered Stacking Chairs',
#        'Global Deluxe High-Back Office Chair in Storm',
#        'Hon Deluxe Fabric Upholstered Stacking Chairs, Squared Back'],
#       dtype=object)

# %%
df.tail(10)
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 9984    9985  CA-2015-100251   5/17/2015   5/23/2015  Standard Class
# 9985    9986  CA-2015-100251   5/17/2015   5/23/2015  Standard Class
# 9986    9987  CA-2016-125794   9/29/2016   10/3/2016  Standard Class
# 9987    9988  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9988    9989  CA-2017-163629  11/17/2017  11/21/2017  Standard Class
# 9989    9990  CA-2014-110422   1/21/2014   1/23/2014    Second Class
# 9990    9991  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9991    9992  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9992    9993  CA-2017-121258   2/26/2017    3/3/2017  Standard Class
# 9993    9994  CA-2017-119914    5/4/2017    5/9/2017    Second Class
#
#      Customer ID     Customer Name    Segment        Country         City  \
# 9984    DV-13465  Dianna Vittorini   Consumer  United States   Long Beach
# ...

# %%
df.head(10)
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       3  CA-2016-138688   6/12/2016   6/16/2016    Second Class    DV-13045
# 3       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 4       5  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 5       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 6       7  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 7       8  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 8       9  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 9      10  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name    Segment        Country             City  ...  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   object
#  3   Ship Date      9994 non-null   object
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.['Profit'].sort_values()
# Out:
#   Cell In[76], line 1
#     df.['Profit'].sort_values()
#        ^
# SyntaxError: invalid syntax
