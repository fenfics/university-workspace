# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from mlxtend.frequent_patterns import apriori , association_rules

# %%
raw_data = pd.read_excel('./data/MarketBasketOptimization.xlsx',header = None)
#openpyxl

# %%
dataset = []
for i in range(0 , len(raw_data)):  ###ลูปตั้งแต่แถวแรกยั้นแถวสุดท้าย
    tmp = []
    for j in range(0 , len(raw_data.loc[i])) :
        if raw_data.loc[i,j] is not np.nan :
            tmp.append(raw_data.loc[i,j])
    dataset.append(tmp)

# %%
dataset[3]
# Out:
# ['turkey', 'avocado']

# %%
from mlxtend.preprocessing import TransactionEncoder
TE = TransactionEncoder()
tmp_dataset = TE.fit_transform(dataset)

# %%
tmp_dataset ###True ถูกซื้อ False ไม่ถูกซื้อ
# Out:
# array([[False,  True,  True, ...,  True, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False,  True, False]], shape=(7501, 120))

# %%
df = pd.DataFrame(tmp_dataset , columns = TE.columns_)
df.head(2)
# Out:
#     asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0       False     True               True      False     True        False
# 1       False    False              False      False    False        False
#
#    bacon  barbecue sauce  black tea  blueberries  ...  turkey  vegetables mix  \
# 0  False           False      False        False  ...   False            True
# 1  False           False      False        False  ...   False           False
#
#    water spray  white wine  whole weat flour  whole wheat pasta  \
# 0        False       False              True              False
# 1        False       False             False              False
#
#    whole wheat rice   yams  yogurt cake  zucchini
# 0             False   True        False     False
# 1             False  False        False     False
#
# [2 rows x 120 columns]

# %%
itemset = apriori(df.drop('mineral water',axis=1), min_support=0.01, use_colnames=True )
itemset
# Out:
#       support                       itemsets
# 0    0.020397                      (almonds)
# 1    0.033329                      (avocado)
# 2    0.010799               (barbecue sauce)
# 3    0.014265                    (black tea)
# 4    0.011465                   (body spray)
# ..        ...                            ...
# 206  0.020931          (spaghetti, tomatoes)
# 207  0.016531            (spaghetti, turkey)
# 208  0.014131  (spaghetti, whole wheat rice)
# 209  0.010532   (spaghetti, chocolate, eggs)
# 210  0.010932   (spaghetti, milk, chocolate)
#
# [211 rows x 2 columns]

# %%
rule = association_rules( itemset , metric='confidence', min_threshold=0.25 )
rule
# Out:
#                antecedents     consequents  antecedent support  \
# 0                (burgers)          (eggs)            0.087188
# 1                (burgers)  (french fries)            0.087188
# 2                (chicken)     (spaghetti)            0.059992
# 3            (cooking oil)     (chocolate)            0.051060
# 4                 (salmon)     (chocolate)            0.042528
# 5                 (shrimp)     (chocolate)            0.071457
# 6            (cooking oil)     (spaghetti)            0.051060
# 7          (herb & pepper)          (eggs)            0.049460
# 8                 (turkey)          (eggs)            0.062525
# 9      (frozen vegetables)     (spaghetti)            0.095321
# 10         (grated cheese)     (spaghetti)            0.052393
# 11         (herb & pepper)   (ground beef)            0.049460
# 12           (ground beef)     (spaghetti)            0.098254
# 13         (herb & pepper)     (spaghetti)            0.049460
# ...
